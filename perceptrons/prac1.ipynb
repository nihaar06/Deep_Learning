# %%
import pandas as pd
import numpy as np

# %%
X=np.array([[1,1],[1,0],[0,1],[0,0]])
y=np.array([1,1,1,0])
X,y
# Out:
# (array([[1, 1],
#         [1, 0],
#         [0, 1],
#         [0, 0]]),
#  array([1, 1, 1, 0]))

# %%
def step_function(z):
    return 1 if z>=0 else 0

# %%
w=np.zeros(2)
b=0.0

learning_rate=0.1
epochs=10

# %%
for epoch in range(epochs):
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        z=np.dot(w,X[i])+b
        y_pred=step_function(z)
        error=y_pred-y[i]
        w=w+learning_rate*error*X[i]
        b=b+learning_rate*error
        print(f"Input:{X[i]}, Predicted:{y_pred}, Actual:{y[i]}, w:{w}, b:{b}")
# Out:
# Epoch 1
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.0
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.0
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.0
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.1
# Epoch 2
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.1
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.1
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.1
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.2
# Epoch 3
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.2
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.2
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.2
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.30000000000000004
# Epoch 4
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.30000000000000004
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.30000000000000004
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.30000000000000004
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.4
# Epoch 5
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.4
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.4
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.4
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.5
# Epoch 6
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.5
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.5
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.5
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.6
# Epoch 7
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.6
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.6
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.6
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.7
# Epoch 8
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.7
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.7
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.7
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.7999999999999999
# Epoch 9
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.7999999999999999
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.7999999999999999
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.7999999999999999
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.8999999999999999
# Epoch 10
# Input:[1 1], Predicted:1, Actual:1, w:[0. 0.], b:0.8999999999999999
# Input:[1 0], Predicted:1, Actual:1, w:[0. 0.], b:0.8999999999999999
# Input:[0 1], Predicted:1, Actual:1, w:[0. 0.], b:0.8999999999999999
# Input:[0 0], Predicted:1, Actual:0, w:[0. 0.], b:0.9999999999999999

# %%
print("\nFinal Weights:",w)
print("Final Bias:",b)
# Out:
# Final Weights: [0. 0.]
# Final Bias: 0.9999999999999999

# %%
print("\nTesting XOR gate")
for i in range(len(X)):
    z=np.dot(w,X[i])+b
    prediction=step_function(z)
    print("Input:",X[i], "Predicted:",prediction)
# Out:
# Testing XOR gate
# Input: [1 1] Predicted: 1
# Input: [1 0] Predicted: 1
# Input: [0 1] Predicted: 1
# Input: [0 0] Predicted: 1
