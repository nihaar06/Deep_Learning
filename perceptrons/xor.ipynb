# %%
import pandas as pd
import numpy as np

# %%
X=np.array([[0,0],[0,1],[1,0],[1,1]])
y=np.array([0,1,1,0])
X,y
# Out:
# (array([[0, 0],
#         [0, 1],
#         [1, 0],
#         [1, 1]]),
#  array([0, 1, 1, 0]))

# %%
def step_function(z):
    return 1 if z>=0 else 0

# %%
w=np.zeros(2)
b=0

learning_rate=0.1
epochs=10

for epoch in range(epochs):
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        z=np.dot(w,X[i])+b
        y_pred=step_function(z)
        error=y_pred-y[i]
        w=w+learning_rate*error*X[i]
        b=b+learning_rate*error
        print(f"Input:{X[i]}, Predicted:{y_pred}, Actual:{y[i]}, Weights:{w}, Bias:{b}")
# Out:
# Epoch 1
# Input:[0 0], Predicted:1, Actual:0, Weights:[0. 0.], Bias:0.1
# Input:[0 1], Predicted:1, Actual:1, Weights:[0. 0.], Bias:0.1
# Input:[1 0], Predicted:1, Actual:1, Weights:[0. 0.], Bias:0.1
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.1 0.1], Bias:0.2
# Epoch 2
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.1 0.1], Bias:0.30000000000000004
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.1 0.1], Bias:0.30000000000000004
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.1 0.1], Bias:0.30000000000000004
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.2 0.2], Bias:0.4
# Epoch 3
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.2 0.2], Bias:0.5
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.2 0.2], Bias:0.5
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.2 0.2], Bias:0.5
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.3 0.3], Bias:0.6
# Epoch 4
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.3 0.3], Bias:0.7
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.3 0.3], Bias:0.7
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.3 0.3], Bias:0.7
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.4 0.4], Bias:0.7999999999999999
# Epoch 5
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.4 0.4], Bias:0.8999999999999999
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.4 0.4], Bias:0.8999999999999999
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.4 0.4], Bias:0.8999999999999999
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.5 0.5], Bias:0.9999999999999999
# Epoch 6
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.5 0.5], Bias:1.0999999999999999
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.5 0.5], Bias:1.0999999999999999
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.5 0.5], Bias:1.0999999999999999
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.6 0.6], Bias:1.2
# Epoch 7
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.6 0.6], Bias:1.3
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.6 0.6], Bias:1.3
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.6 0.6], Bias:1.3
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.7 0.7], Bias:1.4000000000000001
# Epoch 8
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.7 0.7], Bias:1.5000000000000002
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.7 0.7], Bias:1.5000000000000002
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.7 0.7], Bias:1.5000000000000002
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.8 0.8], Bias:1.6000000000000003
# Epoch 9
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.8 0.8], Bias:1.7000000000000004
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.8 0.8], Bias:1.7000000000000004
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.8 0.8], Bias:1.7000000000000004
# Input:[1 1], Predicted:1, Actual:0, Weights:[0.9 0.9], Bias:1.8000000000000005
# Epoch 10
# Input:[0 0], Predicted:1, Actual:0, Weights:[0.9 0.9], Bias:1.9000000000000006
# Input:[0 1], Predicted:1, Actual:1, Weights:[0.9 0.9], Bias:1.9000000000000006
# Input:[1 0], Predicted:1, Actual:1, Weights:[0.9 0.9], Bias:1.9000000000000006
# Input:[1 1], Predicted:1, Actual:0, Weights:[1. 1.], Bias:2.0000000000000004

# %%
print("\nFinal Weights:",w)
print("Final Bias:",b)
# Out:
# Final Weights: [1. 1.]
# Final Bias: 2.0000000000000004

# %%
print("\nTesting XOR gate")
for i in range(len(X)):
    z=np.dot(w,X[i])+b
    y_pred=step_function(z)
    prediction=step_function(z)
    print("Input:",X[i], "Predicted:",prediction)
# Out:
# Testing XOR gate
# Input: [0 0] Predicted: 1
# Input: [0 1] Predicted: 1
# Input: [1 0] Predicted: 1
# Input: [1 1] Predicted: 1
